# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize']=5,4 
#5 inches wide and 4 inches tall

# %%
# defining axes, ticks, and grids
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
fig = plt.figure() # create blank figure

#This parameter is the dimensions [left, bottom, width, height] of the new axes.
ax.plot(x,y)
ax = fig.add_axes([.1,.1,1,1])

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

#set axis limit
ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

#set axis limit
ax.set_xlim([1,9])
ax.set_ylim([0,5])

#set ticks
ax.set_xticks([0,1,2,3,4,6,7,9,10]) # ticks will change the axes limit
ax.set_yticks([0,1,2,3,4,5])

ax.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

#set axis limit
ax.set_xlim([1,9])
ax.set_ylim([0,5])

ax.grid()
ax.plot(x,y)

# %%
fig = plt.figure()
fig,(ax1,ax2) = plt.subplots(1,2)

ax1.plot(x)
ax2.plot(x,y)
