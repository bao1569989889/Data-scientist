# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn

from pylab import rcParams

from sklearn.cluster import DBSCAN
from collections import Counter

# %%
address = '/Users/tank/Desktop/python/linkedin_python_Exercise Files/Data/iris.data.csv'

df = pd.read_csv(address,header=None, sep=',')
df.columns = ['Sepal Length','Sepal Width','Petal Length','Petal Width','Species']

data = df.iloc[:,0:4].values
target = df.iloc[:,4].values

df[:5]
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Train your model and identify outliers

# %%
model = DBSCAN(eps=0.8,min_samples=19).fit(data)
print(model)
# Out:
# DBSCAN(eps=0.8, min_samples=19)

# %% [markdown]
# ### Visualize your results

# %%
outliers_df = pd.DataFrame(data)

print(Counter(model.labels_))
print(outliers_df[model.labels_==-1])
# Out:
# Counter({1: 94, 0: 50, -1: 6})
#        0    1    2    3
# 98   5.1  2.5  3.0  1.1
# 105  7.6  3.0  6.6  2.1
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 122  7.7  2.8  6.7  2.0
# 131  7.9  3.8  6.4  2.0

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

colors = model.labels_

ax.scatter(data[:,2],data[:,1], c=colors, s=120)
ax.set_xlabel('Petal Length')
ax.set_ylabel('Sepatl width')
plt.title('DBSCAN for Outliers Detection')
# Out:
# Text(0.5, 1.0, 'DBSCAN for Outliers Detection')
